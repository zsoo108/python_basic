# %% [markdown]
# # python 첫 수업
# - python 설치
# - 가상환경 세팅
# - vscode 확장프로그램 설치
#     - python
#     - jupyter
# - .ipynb파일 생성

# %%
print("1+2")
# Out:
# 1+2

# %%
print(1+2)
# Out:
# 3

# %%
if 4 in [1,2,3,4]:
    print("4가 있습니다.")
# Out:
# 4가 있습니다.
