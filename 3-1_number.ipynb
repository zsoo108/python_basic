# %% [markdown]
# # 1. 숫자형은 어떻게 만들고 사용할까?

# %%
a = 123

# %%
a
# Out:
# 123

# %%
print(a)
# Out:
# 123

# %%
a = -178

# %%
a
# Out:
# -178

# %%
print(f"vaule of a is {a}")
# Out:
# vaule of a is -178

# %%
a=0
a
# Out:
# 0

# %%
a = 1.2
a
# Out:
# 1.2

# %%
a = -3.45
a
# Out:
# -3.45

# %%
a = 4.24E10
a
# Out:
# 42400000000.0

# %%
a = 4.24e-10
a
# Out:
# 4.24e-10

# %%
a = 0o177
print(a)
# Out:
# 127

# %%
a = 0x8ff
b = 0xabc
print(b)
# Out:
# 2748

# %%
a
# Out:
# 2303

# %%
print (a,b)
# Out:
# 2303 2748

# %% [markdown]
# # 2. 숫자를 활용하기 위한 연산자

# %% [markdown]
# ## 사칙연산

# %%
a=3
b=4

# %%
a+b
# Out:
# 7

# %%
a-b
# Out:
# -1

# %%
a*b
# Out:
# 12

# %%
a/b
# Out:
# 0.75

# %% [markdown]
# ## 제곱(**) 연산자

# %%
a**b
# Out:
# 81

# %% [markdown]
# ## 나머지 연산자

# %%
7%3
# Out:
# 1

# %%
3%7
# Out:
# 3

# %% [markdown]
# ## 몫(//) 연산자

# %%
7//4
# Out:
# 1

# %%
7/4
# Out:
# 1.75
