# %% [markdown]
# # 튜플 자료형

# %% [markdown]
# ## 1. 튜플은 어떻게 만들까?

# %%
t1 = ()
t2 = (1,)
t3 = (1,2,3)
t4 = 1,2,3 # 괄호 생략 가능
t5 = ('a','b',('ab','cd'))

# %% [markdown]
# ## 2. 튜플의 요소값을 삭제, 변경하면 어떻게 될까?

# %%
t1 = (1,2,'a','b')
del t1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 t1 = (1,2,'a','b')
# ----> 2 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1[0]
# Out:
# 1

# %%
t1[0] = 'c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t1[0] = 'c'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## 3. 튜플 다루기

# %% [markdown]
#  인덱싱 하기

# %%
t1
# Out:
# (1, 2, 'a', 'b')

# %%
t1[2]
# Out:
# 'a'

# %%
t1[-2]
# Out:
# 'a'

# %% [markdown]
#  슬라이싱하기

# %%
t1
# Out:
# (1, 2, 'a', 'b')

# %%
t1[2:]
# Out:
# ('a', 'b')

# %%
t1[0:2]
# Out:
# (1, 2)

# %%
t1[1:3]
# Out:
# (2, 'a')

# %% [markdown]
#  튜플 더하기

# %%
t1
# Out:
# (1, 2, 'a', 'b')

# %%
t2 = (3,4)
t3 = t1 + t2
t3
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %% [markdown]
#  튜플 곱하기

# %%
t3 = t2*3
t3
# Out:
# (3, 4, 3, 4, 3, 4)

# %% [markdown]
#  튜플 길이 구하기

# %%
t1
# Out:
# (1, 2, 'a', 'b')

# %%
len(t1)
# Out:
# 4

# %%
t3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
len(t3)
# Out:
# 6
