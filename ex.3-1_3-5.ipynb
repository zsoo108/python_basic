# %%
a = 123
a
# Out:
# 123

# %%
print (a)
# Out:
# 123

# %%
print(f"value of a is {a}")
# Out:
# value of a is 123

# %%
a=0
print(f"value of a is {a}")
# Out:
# value of a is 0

# %%
a = 4.24E10
a
# Out:
# 42400000000.0

# %%
a = 4.24e-10
a
# Out:
# 4.24e-10

# %%
a=0o177
a
# Out:
# 127

# %%
b= 0xabc
a=0x8ff
b
# Out:
# 2748

# %%
print (a,b)
# Out:
# 2303 2748

# %%
a=3
b=4
a+b
# Out:
# 7

# %%
a-b
# Out:
# -1

# %%
a*b
# Out:
# 12

# %%
a/b
# Out:
# 0.75

# %%
a**b
# Out:
# 81

# %%
7%3
# Out:
# 1

# %%
3%7
# Out:
# 3

# %%
7//4
# Out:
# 1

# %%
7/4
# Out:
# 1.75

# %%
food = "python's faverite food is perl"
food
# Out:
# "python's faverite food is perl"

# %%
say = '"python is very easy." he says.'
say
# Out:
# '"python is very easy." he says.'

# %%
food = 'python\'s faverite food is perl'
food
# Out:
# "python's faverite food is perl"

# %%
say = "\"python is very easy.\" he says."
say
# Out:
# '"python is very easy." he says.'

# %%
print(say)
# Out:
# "python is very easy." he says.

# %%
multline = "life is too short\nYou need python"
print(multline)
# Out:
# life is too short
# You need python

# %%
multline = """
life is too short
You need python."""
print(multline)
# Out:
# life is too short
# You need python.

# %%
multline = '''
life is too short
You need python.'''
print(multline)
# Out:
# life is too short
# You need python.

# %%
head = 'python'
tail = ' is fun!'
head + tail
# Out:
# 'python is fun!'

# %%
a = "python"
a*2
# Out:
# 'pythonpython'

# %%
print("="*30)
print("hjs")
print("="*30)
# Out:
# ...
# hjs
# ...

# %%
len (a)
# Out:
# 6

# %%
a = "Life is too short, You need Python"
len(a)
# Out:
# 34

# %%
a[1]
# Out:
# 'i'

# %%
b = a[2]+a[3]+a[4]
b
# Out:
# 'fe '

# %%
a[0:4]
# Out:
# 'Life'

# %%
a[28:]
# Out:
# 'Python'

# %%
a[-6:]
# Out:
# 'Python'

# %%
a = "20260811sunny"
date = a[:8]
date
# Out:
# '20260811'

# %%
a = "pithon"
a
# Out:
# 'pithon'

# %%
a[1]='y'
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 a[1]='y'
#       2 a
#
# TypeError: 'str' object does not support item assignment

# %%
"i eat %d apples." %3
# Out:
# 'i eat 3 apples.'

# %%
"i eat %d apples." %five
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 "i eat %d apples." %five
#
# NameError: name 'five' is not defined

# %%
"i eat %s apples."%"five"
# Out:
# 'i eat five apples.'

# %%
num = 3
"i eat %d apples." %num
# Out:
# 'i eat 3 apples.'

# %%
number = 10
day = 'three'
"i ate %d apples, so i was sick for %s days." %(number, day)
# Out:
# 'i ate 10 apples, so i was sick for three days.'

# %%
"i have %s apples"%3
# Out:
# 'i have 3 apples'

# %%
"i have %s apples"%3.234
# Out:
# 'i have 3.234 apples'

# %%
"i have %d apples"%3.234
# Out:
# 'i have 3 apples'

# %%
"i have %f apples"%3.234
# Out:
# 'i have 3.234000 apples'

# %%
"i have %d%% apples"%99
# Out:
# 'i have 99% apples'

# %%
a="%10s"%"hi"
a
# Out:
# '        hi'

# %%
len(a)
# Out:
# 10

# %%
a[-2]
# Out:
# 'h'

# %%
a="%-10s"%"hi"
a
# Out:
# 'hi        '

# %%
a="%-10sJANI"%"hi"
a
# Out:
# 'hi        JANI'

# %%
a= "%10.4F"%3.423234
a
# Out:
# '    3.4232'

# %%
len(a)
# Out:
# 10

# %%
"i eat {} apples.".format(1)
# Out:
# 'i eat 1 apples.'

# %%
"i eat {} apples.".format('two')
# Out:
# 'i eat two apples.'

# %%
num = 3
"i eat {} apples.".format(num)
# Out:
# 'i eat 3 apples.'

# %%
number = 10
day = 'three'
"I ate {0} apples, so i was sick for {1} days.".format(number, day)
# Out:
# 'I ate 10 apples, so i was sick for three days.'

# %%
"i ate {number} apples, so i was sick for {day} days.".format(day=3, number=10)
# Out:
# 'i ate 10 apples, so i was sick for 3 days.'

# %%
"i ate {0} apples, so i was sick for {day} days.".format(10, day=3)
# Out:
# 'i ate 10 apples, so i was sick for 3 days.'

# %%
"{:<10}".format('hi')
# Out:
# 'hi        '

# %%
"{:>10}".format('hi')
# Out:
# '        hi'

# %%
"{:^10}".format('hi')
# Out:
# '    hi    '

# %%
"{:=^10}".format('hi')
# Out:
# '====hi===='

# %%
"{:!<10}".format('hi')
# Out:
# 'hi!!!!!!!!'

# %%
"{{and}}".format()
# Out:
# '{and}'

# %%
name = 'hjs'
age = 25
f'나의 이름은 {name}. 나이는 {age}'
# Out:
# '나의 이름은 hjs. 나이는 25'

# %%
f'나의 이름은 {name}. 나이는 내년에{age+1}'
# Out:
# '나의 이름은 hjs. 나이는 내년에26'

# %%
d = {'name':'홍지수', 'age':25}
d
# Out:
# {'name': '홍지수', 'age': 25}

# %%
f'나의 이름은 {d['name']}. 나이는 {d['age']}'
# Out:
# '나의 이름은 홍지수. 나이는 25'

# %%
f"{'hi':<10}"
# Out:
# 'hi        '

# %%
f"{'hi':=^10}"
# Out:
# '====hi===='

# %%
f"{{and}}"
# Out:
# '{and}'

# %%
a = "hobby"
a.count('b')
# Out:
# 2

# %%
a = "python is the best choice"
a.find ('b')
# Out:
# 14

# %%
a.find ('k')
# Out:
# -1

# %%
a.index('b')
# Out:
# 14

# %%
a.index('k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 a.index('k')
#
# ValueError: substring not found

# %%
",".join('abcd')
# Out:
# 'a,b,c,d'

# %%
"!".join('abcd')
# Out:
# 'a!b!c!d'

# %%
"hi".upper()
# Out:
# 'HI'

# %%
"HI".lower()
# Out:
# 'hi'

# %%
a="   hi   "
a.lstrip()
# Out:
# 'hi   '

# %%
a.rstrip()
# Out:
# '   hi'

# %%
a.strip()
# Out:
# 'hi'

# %%
a = "Life is too short"
b = a.replace("Life", "your leg")
b
# Out:
# 'your leg is too short'

# %%
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
a= "Life.. is.. too short"
a.split('..')
# Out:
# ['Life', ' is', ' too short']

# %%
a = 'hi'
a.upper()
# Out:
# 'HI'

# %%
a
# Out:
# 'hi'

# %%
a =a.upper()
a
# Out:
# 'HI'

# %%
t1 = (1,2,'a','b')
t1[0]
# Out:
# 1

# %%
del t1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 del t1[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t1[0]='c'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 t1[0]='c'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (1, 2, 'a', 'b')

# %%
t1[2]
# Out:
# 'a'

# %%
t1[2:]
# Out:
# ('a', 'b')

# %%
t2=(3,4)
t3= t1+t2
t3
# Out:
# (1, 2, 'a', 'b', 3, 4)

# %%
t3 = t2*3
t3
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
len(t1)
# Out:
# 4

# %%
len(t3)
# Out:
# 6

# %%
odd = [1,3,5,7,9]
even = [2,4,6,8,10]
print (odd,even)
# Out:
# [1, 3, 5, 7, 9] [2, 4, 6, 8, 10]

# %%
a = []
a
# Out:
# []

# %%
a = list()
a
# Out:
# []

# %%
a = [1,2,3]
a
# Out:
# [1, 2, 3]

# %%
a[0]
# Out:
# 1

# %%
a[0]+ a[2]
# Out:
# 4

# %%
a = [1,2,3,['a','b','c']]
a
# Out:
# [1, 2, 3, ['a', 'b', 'c']]

# %%
a[-1]
# Out:
# ['a', 'b', 'c']

# %%
a[3][1]
# Out:
# 'b'

# %%
a[-1][-1]
# Out:
# 'c'

# %%
a = [1,2,3]
b = [4,5,6]
a+b
# Out:
# [1, 2, 3, 4, 5, 6]
