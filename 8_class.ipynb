# %% [markdown]
# ## 1. 클래스는 왜 필요한가?

# %%
# 계산기 프로그램을 함수로 만들기
result = 0
def add(num):
    global result
    result += num
    return result

add(3)
# Out:
# 3

# %%
add(4)
# Out:
# 7

# %%
# 계산기 2대가 필요한 상황
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1

def add2(num):
    global result2
    result2 += num
    return result2

add1(3)
print(add1(4))

add2(3)
print(add2(7))
# Out:
# 7
# 10

# %%
# 클래스로 해결

class Calculator:
    #생성자 함수 (클래스 변수 초기화)
    def __init__(self):
        self.result = 0

    def add(self,num):
        self.result += num
        return self.result

    def sub(self, num):
        self.result -= num
        return self.result

# %% [markdown]
# ## 2. 클래스와 객체

# %%
class Cookie:
    pass

# %%
# 객체 생성
a = Cookie()
b = Cookie()

# %% [markdown]
# # 3. 사칙연산 클래스 만들기

# %% [markdown]
# 1) 클래스를 어떻게 만들지 먼저 구상하기
# 2) 클래스 구조 만들기

# %%
class FourCal:
    pass

# %%
# 객체 생성
a = FourCal()
type(a) # a객체는 FourCal의 인스턴스
# Out:
# __main__.FourCal

# %% [markdown]
# 3) 객체에 연산할 숫자 지정하기

# %%
class FourCal:
    # 숫자 2개 입력받는 함수 (메서드)
    def setdata(self,first,second):
        self.first = first
        self.second = second

# %%
a = FourCal()
a.setdata(4,2)

# %%
a.first
# Out:
# 4

# %%
a.second
# Out:
# 2

# %%
a = FourCal()
FourCal.setdata(a, 3, 5)

# %%
a.first
# Out:
# 3

# %%
a.second
# Out:
# 5

# %%
# FourCal 클래스로 2개의 계산기(객체) 생성
a = FourCal()
b = FourCal()

# %%
a.setdata(4,2)
b.setdata(3,7)

print(a.first, a.second)
print(b.first, b.second)
# Out:
# 4 2
# 3 7

# %% [markdown]
# 4) 더하기 기능 만들기

# %%
class FourCal:
    # 숫자 2개 입력받는 함수 (메서드)
    def setdata(self,first,second):
        self.first = first
        self.second = second 

    # 더하기 함수
    def add(self):
        result = self.first + self.second
        return result

# %%
a = FourCal()
a.setdata(4,2)
a.add()
# Out:
# 6

# %% [markdown]
# 5) 곱하기, 빼기, 나누기 기능 만들기

# %%
class FourCal:
    # 숫자 2개 입력받는 함수 (메서드)
    def setdata(self,first,second):
        self.first = first
        self.second = second 

    # 더하기 함수
    def add(self):
        result = self.first + self.second
        return result

    #곱하기 함수
    def mul(self):
        result = self.first * self.second
        return result

    # 빼기 함수
    def sub(self):
        result = self.first - self.second
        return result

    # 나누기 함수
    def div(self):
        result = self.first / self.second
        return result

# %%
a = FourCal()
b = FourCal()

a.setdata(4,2)
b.setdata(3,8)

# %%
a.add()
# Out:
# 6

# %%
a.sub()
# Out:
# 2

# %%
a.mul()
# Out:
# 8

# %%
a.div()
# Out:
# 2.0

# %%
b.add()
# Out:
# 11

# %%
b.sub()
# Out:
# -5

# %%
b.mul()
# Out:
# 24

# %%
b.div()
# Out:
# 0.375

# %% [markdown]
# ## 4. 생성자(Constructor)

# %%
a = FourCal()
a.add()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 a = FourCal()
# ----> 2 a.add()
#
# Cell In[32], line 9, in FourCal.add(self)
#       8     def add(self):
# ----> 9         result = self.first + self.second
#      10         return result
#
# AttributeError: 'FourCal' object has no attribute 'first'

# %%
class FourCal:
    # 생성자 함수
    def __init__(self, first, second):
        self.first = first
        self.second = second

    # 더하기 함수
    def add(self):
        result = self.first + self.second
        return result

    #곱하기 함수
    def mul(self):
        result = self.first * self.second
        return result

    # 빼기 함수
    def sub(self):
        result = self.first - self.second
        return result

    # 나누기 함수
    def div(self):
        result = self.first / self.second
        return result

# %%
a = FourCal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 a = FourCal()
#
# TypeError: FourCal.__init__() missing 2 required positional arguments: 'first' and 'second'

# %%
# FourCal 클래스로 객체가 생성되면 생성자에게 매개변수값이 전달된다.
a = FourCal(4,2)

# %%
a.first
# Out:
# 4

# %%
a.second
# Out:
# 2

# %%
a.add()
# Out:
# 6

# %%
a.div()
# Out:
# 2.0

# %% [markdown]
# ## 5. 클래스의 상속

# %%
#FourCal 클래스를 상속받아 MoreFourCal 클래스 선언
class MoreFourCal(FourCal):
    pass

# %%
a = MoreFourCal(4,2)

# %%
a.add()
# Out:
# 6

# %%
a.mul()
# Out:
# 8

# %%
class MoreFourCal(FourCal):
    # 기능 추가
    def pow(self):
        result = self.first ** self.second
        return result

# %%
a = MoreFourCal(4,2)

# %%
a.pow()
# Out:
# 16

# %%
a.mul()
# Out:
# 8

# %% [markdown]
# ## 6. 메서드 오버라이딩(재정의)

# %%
a = FourCal(4,0)
a.add()
# Out:
# 4

# %%
a.div()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 a.div()
#
# Cell In[52], line 24, in FourCal.div(self)
#      23     def div(self):
# ---> 24         result = self.first / self.second
#      25         return result
#
# ZeroDivisionError: division by zero

# %%
class SafeFourCal(FourCal):
    def div(self):  #FourCal 클래스 div 메서드 재정의
        if self.second == 0:
            return 0
        else:
            return self.first / self .second
            return result

# %%
a = SafeFourCal(4,0)
a.div()
# Out:
# 0

# %% [markdown]
# ## 7. 클래스 변수

# %%
# 클래스 변수 선언
class Family:
    lastname = '홍'

# %%
# 클래스 변수 사용
Family. lastname
# Out:
# '홍'

# %%
son = Family()
daughter = Family()

son.lastname
# Out:
# '홍'

# %%
daughter.lastname
# Out:
# '홍'

# %%
Family.lastname = '추' # 클래스 변수 변경
son.lastname
# Out:
# '추'

# %%
daughter.lastname
# Out:
# '추'

# %% [markdown]
# 클래스 변수와 동일한 이름의 객체변수를 생성하면?

# %%
son.lastname = '최' # 객체변수 생성(클래스 변수와 동일한 이름으로 생성됨)
son.lastname # 객체변수 출력
# Out:
# '최'

# %%
Family.lastname
# Out:
# '추'

# %%
daughter.lastname
# Out:
# '추'
