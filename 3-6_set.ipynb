# %% [markdown]
# # 집합 자료형

# %% [markdown]
# ## 1. 집합 자료형은 어떻게 만들까?

# %%
s1 = set([1,2,3])
s1
# Out:
# {1, 2, 3}

# %%
s2 = set("hello")
s2
# Out:
# {'e', 'h', 'l', 'o'}

# %%
s2[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 s2[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ## 2. 집합자료형의 특징

# %%
s1 = set([1,2,3])
s1
# Out:
# {1, 2, 3}

# %%
# set 자료형에 저장된 값을 인덱싱으로 접근하려면 리스트나 튜플로 변환 후 인덱싱
l1 = list(s1)
l1
# Out:
# [1, 2, 3]

# %%
l1[0]
# Out:
# 1

# %%
t1 = tuple(s1)
t1
# Out:
# (1, 2, 3)

# %%
t1[-1]
# Out:
# 3

# %% [markdown]
# ## 3. 교집합, 합집합, 차집합 구하기

# %%
s1 = set([1,2,3,4,5,6])
s2 = set([4,5,6,7,8,9])

# %% [markdown]
# 교집합 구하기

# %%
s1 & s2
# Out:
# {4, 5, 6}

# %%
s1.intersection(s2)
# Out:
# {4, 5, 6}

# %% [markdown]
# 합집합 구하기

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# 차집합 구하기

# %%
s1 - s2
# Out:
# {1, 2, 3}

# %%
s2 - s1
# Out:
# {7, 8, 9}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
s2.difference(s1)
# Out:
# {7, 8, 9}

# %% [markdown]
# ## 4. 집합 자료형 관련 함수

# %% [markdown]
# add() : 값 1개 추가하기

# %%
s1 = set ([1,2,3])
s1.add(4)
s1
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# update(): 값 여러 개 추가하기

# %%
s1.update([4,5,6])
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# remove() : 특정 값 제거하기

# %%
s1.remove(5)
s1
# Out:
# {1, 2, 3, 4, 6}

# %%
s1.remove(7)
s1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 s1.remove(7)
#       2 s1
#
# KeyError: 7
